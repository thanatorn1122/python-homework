# %% [markdown]
# # แบบฝึกหัด บทที่ 5 ตัวแปรและประเภทข้อมูล

# %%
"""
ชื่อ - สกุล - รหัส

ธนาธร โพธิ์ขาว 6812732109 
"""

# %% [markdown]
# ## 1.	ประเภทของตัวเลขที่ภาษาไพธอนให้การรองรับมีอะไรบ้าง

# %%
"""
คำตอบ
"""

# %% [markdown]
# ## 2.จงแสดงชนิดข้อมูลของตัวแปร a และ b

# %%
"""
a = 15.50
b = ‘Python’ 
จงแสดงชนิดข้อมูลของตัวแปร a และ b
"""

# %%
"""
คำตอบ
"""
a = 15.50
b = "Python"
print("{} {}".format(a,type(a)))
print("{} {}".format(b,type(b)))
# Out:
# 15.5 <class 'float'>
# Python <class 'str'>

# %% [markdown]
# ## 3.จงใช้คำสั่ง print() เพื่อแสดงสตริงต่อไปนี้
#
# - Jane's teacher says "You have to study hard" –

# %%
"""
คำตอบ
"""

# %% [markdown]
# ## 4.	จงแสดงผลลัพธ์ของคำสั่งต่อไปนี้

# %%
"""
print("{2} {0} {1}".format("apple", 
         "pineapple", 
         "banana"))
"""

# %% [markdown]
# ## 5. กำหนดให้ตัวแปร

# %%
"""
pi = 3.141592653589
จงแสดงค่าของตัวแปร pi ออกทางหน้าจอให้มีทศนิยมเพียง 3 จุด
"""

# %%
"""
คำตอบ
"""
pi = 3.141592653589
print("{:.3f}".format(pi))
# Out:
# 3.142

# %% [markdown]
# ## 6.กำหนดให้
#
# str = "Python Programming"
# ให้แสดงเฉพาะ "programming"
# msg = "pyton programming"
#
# จงหาผลลัพธ์ของ str[7:]

# %%
"""
คำตอบ
"""
str = "python programming"
msg = "programming"
print(str[7:18])
# Out:
# programming

# %% [markdown]
# ## 7.จงอธิบายความแตกต่างระหว่างลิสต์และทัพเพิล

# %%
"""
คำตอบ
"""

# %%
a = 10
b = 20
b=a
a=b
b=c
# ให้ทำการสลับค่า a และ b

print("a : {} , b: {}".format(a,b))
# ผลที่คาดหวังคือ
# a : 10 , b: 20
# Out:
# a : 20 , b: 10

# %%
a = 10
b = 20

# parallel assigment
a, b=b, a
print("a : {} , b: {}".format(a,b))
# ผลที่คาดหวังคือ

# %%
name_ = "thanatorn"
